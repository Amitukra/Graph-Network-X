# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitukra/Graph-Network-X/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Scatter plot by help of relplot
sns.relplot(x="total_bill", y="tip", data=data) # by default relplot kind ="scatter"

# %%
sns.relplot(x="total_bill",y="tip",kind="line", data=data)

# %%
# with hue parameter

sns.relplot(x="total_bill", y="tip", hue="sex", data=data)

# %%
sns.relplot(x="total_bill", y="tip", hue="sex",style="smoker", data=data)

# %%
sns.relplot(x="total_bill",y="tip", hue="sex", style="smoker", size="size", sizes=(15,300), data=data)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="smoker", data = data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# lecture-2

# %% [markdown]
# # categorial scatter plot

# %%
# x-axis --> catogirical data
# y-axis --> Numerical data

# %%
plt.style.use("fivethirtyeight")

# %%
Data = sns.load_dataset("tips")

# %%
Data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="day", y="tip", data =Data)

# %%
sns.catplot(x="day", y="tip", jitter=0.25, data= Data)

# %%
# swarm plot

# %%
sns.catplot(x= "day", y="tip", kind="swarm", data = Data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
 sns.catplot(x="day", y="tip", kind = "swarm",hue = "sex",data = Data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="day",y="tip",data = Data)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# lecture -3

# %%
# Boxplot

# %%
# univeriate  plot

# %%
data= sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data["tip"])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(data["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
# for plot the catogical plot
sns.catplot(x="day", y ="total_bill", kind="box",data=data)

# %%
sns.catplot(x="day", y="total_bill", hue ='sex',kind="box", data =data)

# %%
# violinplots

# %%
 data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(data["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.catplot(x="day", y ="total_bill", kind="violin", data =data)

# %%
sns.catplot(x="day", y="total_bill", kind = "violin", hue ="sex", data= data )

# %%
sns.catplot(x="day", y="total_bill",kind="violin",split= True, hue ="sex",data =data)

# %%
# barplot and countplot

# %%
#barplot

# %%
sns.catplot(x="smoker", y="total_bill",kind ="bar", data =data)

# %%
sns.catplot(x="smoker", y="total_bill", kind ="bar",hue ="sex", data = data) # by defaut it calculate estimator =mean

# %%
sns.catplot(x="smoker", y="total_bill", kind="bar", hue ="sex",estimator=np.median, data =data)

# %%
sns.catplot(x="smoker", y="total_bill", kind="bar", hue ="sex",estimator=np.std, data =data)

# %%
sns.catplot(x="smoker", y="total_bill", kind="bar", hue ="sex",estimator=np.var, data =data)

# %%
# countplot

# %%
# count plot is use for find number count as catogirical way

# %%
sns.catplot(x="sex", kind="count",data=data)

# %%
sns.catplot(x="smoker",kind="count", hue="sex",data =data)

# %%
# Heatmap

# %%
flights=sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x =flights.pivot_table(index="year", columns ="month", values ="passengers", aggfunc="sum")
# Out:
# <ipython-input-50-25423d4f4879>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   x =flights.pivot_table(index="year", columns ="month", values ="passengers", aggfunc="sum")

# %%
x.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.heatmap(x)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5, annot= True,fmt="d")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
#clustermap

# %%
sns.clustermap(x)

# %%
sns.clustermap(x, z_score=True,annot=True,row_cluster=False,metric='correlation')

# %%
sns.clustermap(x,z_score=0,annot=True,col_cluster=False,metric="correlation")

# %%
# joinplot

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x="total_bill",y="tip",data=data) #by default kind = "scatter"

# %%
sns.jointplot(x="total_bill", y="tip", kind="kde", data=data)

# %%
sns.jointplot(x="total_bill", y="tip", kind="hex", data=data)

# %%
sns.jointplot(x="total_bill",y="tip", kind="reg", data= data)

# %%
# pairplot

# %%
iris =sns.load_dataset("iris")

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 106           4.9          2.5           4.5          1.7  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 14            5.8          4.0           1.2          0.2     setosa
# 119           6.0          2.2           5.0          1.5  virginica
# 38            4.4          3.0           1.3          0.2     setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue="species")

# %%
# displot

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["age"].fillna(titanic["age"].mean(), inplace=True)
# Out:
# <ipython-input-74-48015f624d96>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic["age"].fillna(titanic["age"].mean(), inplace=True)

# %%
sns.distplot(titanic["age"])
# Out:
# <ipython-input-75-4219f74d0e29>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic["age"],kde=False)
# Out:
# <ipython-input-76-c58e977aa664>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["age"],kde=False)
# <Axes: xlabel='age'>

# %%
sns.distplot(titanic["age"], hist=False)
# Out:
# <ipython-input-77-8fc99a9ec118>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["age"], hist=False)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic["age"],kde=False, hist=False, rug=True)
# Out:
# <ipython-input-78-86d1f76ed35d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["age"],kde=False, hist=False, rug=True)
# <Axes: xlabel='age'>

# %%
sns.distplot(titanic[titanic["survived"]==1]["age"])
sns.distplot(titanic[titanic["survived"]==0]["age"])
# Out:
# <ipython-input-79-15b0933af65a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["survived"]==1]["age"])
# <ipython-input-79-15b0933af65a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["survived"]==0]["age"])
# ...
